# %% [markdown]
# Pandas is one of the most important python libraries for data analysis, data cleaning, data manipulation.

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %% [markdown]
# - 1 D datastructure (Series)
# - 2 D datastructure (DataFrame)

# %% [markdown]
# <h2>Data Frame</h2>

# %%
data = {
    "Name":["Rahul","Krish","Mohit"],
    "Course":["Math","React","Java"],
    "Age":[23,24,25]
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#     Name Course  Age
# 0  Rahul   Math   23
# 1  Krish  React   24
# 2  Mohit   Java   25

# %%
type(df)
# Out:
# pandas.DataFrame

# %% [markdown]
# <h2>Series</h2>

# %%
s = pd.Series([34,54,23])

# %%
s
# Out:
# 0    34
# 1    54
# 2    23
# dtype: int64

# %%
type(s)
# Out:
# pandas.Series

# %% [markdown]
# <h2>Sample Dataset</h2>

# %%
df = pd.DataFrame({
    "Name":["Amit","Riya","John","Sara","Amit","Sneha"],
    "Age":[22,25,30,None,20,31],
    "Salary":[50000,60000,70000,65000,50000,63000],
    "City":["Delhi","Mumbai","Delhi","Pune","Delhi","Pune"]
})

# %%
df
# Out:
#     Name   Age  Salary    City
# 0   Amit  22.0   50000   Delhi
# 1   Riya  25.0   60000  Mumbai
# 2   John  30.0   70000   Delhi
# 3   Sara   NaN   65000    Pune
# 4   Amit  20.0   50000   Delhi
# 5  Sneha  31.0   63000    Pune

# %% [markdown]
# To Show top rows (head())

# %%
df.head(2)
# Out:
#    Name   Age  Salary    City
# 0  Amit  22.0   50000   Delhi
# 1  Riya  25.0   60000  Mumbai

# %% [markdown]
# To show bottom rows (tail())

# %%
df.tail(3)
# Out:
#     Name   Age  Salary   City
# 3   Sara   NaN   65000   Pune
# 4   Amit  20.0   50000  Delhi
# 5  Sneha  31.0   63000   Pune

# %%
df.shape #(rows,columns)
# Out:
# (6, 4)

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Salary', 'City'], dtype='str')

# %%
df.describe()
# Out:
#              Age        Salary
# count   5.000000      6.000000
# mean   25.600000  59666.666667
# std     4.827007   8164.965809
# min    20.000000  50000.000000
# 25%    22.000000  52500.000000
# 50%    25.000000  61500.000000
# 75%    30.000000  64500.000000
# max    31.000000  70000.000000

# %%
df.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    6 non-null      str
#  1   Age     5 non-null      float64
#  2   Salary  6 non-null      int64
#  3   City    6 non-null      str
# dtypes: float64(1), int64(1), str(2)
# memory usage: 324.0 bytes

# %%
df.dtypes
# Out:
# Name          str
# Age       float64
# Salary      int64
# City          str
# dtype: object

# %%
import numpy as np

# %%
df = pd.DataFrame({
    "Name":["Amit","Riya","John","Sara","Amit","Sneha"],
    "Age":[22,25,30,None,20,31],
    "Salary":[50000,60000,None,65000,None,63000],
    "City":["Delhi",np.nan,"Delhi","Pune","Delhi",None]
})

# %%
df
# Out:
#     Name   Age   Salary   City
# 0   Amit  22.0  50000.0  Delhi
# 1   Riya  25.0  60000.0    NaN
# 2   John  30.0      NaN  Delhi
# 3   Sara   NaN  65000.0   Pune
# 4   Amit  20.0      NaN  Delhi
# 5  Sneha  31.0  63000.0    NaN

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    6 non-null      str
#  1   Age     5 non-null      float64
#  2   Salary  4 non-null      float64
#  3   City    4 non-null      str
# dtypes: float64(2), str(2)
# memory usage: 324.0 bytes

# %%
df
# Out:
#     Name   Age   Salary   City
# 0   Amit  22.0  50000.0  Delhi
# 1   Riya  25.0  60000.0    NaN
# 2   John  30.0      NaN  Delhi
# 3   Sara   NaN  65000.0   Pune
# 4   Amit  20.0      NaN  Delhi
# 5  Sneha  31.0  63000.0    NaN

# %%
df.isnull()
# Out:
#     Name    Age  Salary   City
# 0  False  False   False  False
# 1  False  False   False   True
# 2  False  False    True  False
# 3  False   True   False  False
# 4  False  False    True  False
# 5  False  False   False   True

# %%
df.isnull().sum()
# Out:
# Name      0
# Age       1
# Salary    2
# City      2
# dtype: int64

# %%
len(df)
# Out:
# 6

# %%
df.isnull().sum()/len(df)
# Out:
# Name      0.000000
# Age       0.166667
# Salary    0.333333
# City      0.333333
# dtype: float64

# %%
len(df)
# Out:
# 6

# %%
df.isnull().sum()/len(df)*100
# Out:
# Name       0.000000
# Age       16.666667
# Salary    33.333333
# City      33.333333
# dtype: float64

# %%
df["Salary_spike"] = df['Salary']*0.1

# %%
df
# Out:
#     Name   Age   Salary   City  Salary_spike
# 0   Amit  22.0  50000.0  Delhi        5000.0
# 1   Riya  25.0  60000.0    NaN        6000.0
# 2   John  30.0      NaN  Delhi           NaN
# 3   Sara   NaN  65000.0   Pune        6500.0
# 4   Amit  20.0      NaN  Delhi           NaN
# 5  Sneha  31.0  63000.0    NaN        6300.0

# %%
df['Salary_spike_filled'] = df['Salary_spike'].fillna(2000)

# %%
df
# Out:
#     Name   Age   Salary   City  Salary_spike  Salary_spike_filled
# 0   Amit  22.0  50000.0  Delhi        5000.0               5000.0
# 1   Riya  25.0  60000.0    NaN        6000.0               6000.0
# 2   John  30.0      NaN  Delhi           NaN               2000.0
# 3   Sara   NaN  65000.0   Pune        6500.0               6500.0
# 4   Amit  20.0      NaN  Delhi           NaN               2000.0
# 5  Sneha  31.0  63000.0    NaN        6300.0               6300.0

# %%
df['City'] = df['City'].fillna("Unknown")

# %%
df
# Out:
#     Name   Age   Salary     City  Salary_spike  Salary_spike_filled
# 0   Amit  22.0  50000.0    Delhi        5000.0               5000.0
# 1   Riya  25.0  60000.0  Unknown        6000.0               6000.0
# 2   John  30.0      NaN    Delhi           NaN               2000.0
# 3   Sara   NaN  65000.0     Pune        6500.0               6500.0
# 4   Amit  20.0      NaN    Delhi           NaN               2000.0
# 5  Sneha  31.0  63000.0  Unknown        6300.0               6300.0

# %%
df['Salary'].mean()
# Out:
# np.float64(59500.0)

# %%
df['Salary_filled'] = df['Salary'].fillna(df['Salary'].mean())

# %%
df
# Out:
#     Name   Age   Salary     City  Salary_spike  Salary_spike_filled  \
# 0   Amit  22.0  50000.0    Delhi        5000.0               5000.0
# 1   Riya  25.0  60000.0  Unknown        6000.0               6000.0
# 2   John  30.0      NaN    Delhi           NaN               2000.0
# 3   Sara   NaN  65000.0     Pune        6500.0               6500.0
# 4   Amit  20.0      NaN    Delhi           NaN               2000.0
# 5  Sneha  31.0  63000.0  Unknown        6300.0               6300.0
#
#    Salary_filled
# 0        50000.0
# 1        60000.0
# 2        59500.0
# 3        65000.0
# 4        59500.0
# 5        63000.0

# %%
df = pd.DataFrame({
    "Name":["Amit","Riya","John","Sara","Amit","Sneha"],
    "Age":[22,25,30,None,20,31],
    "Salary":[50000,60000,None,65000,None,63000],
    "City":["Delhi",np.nan,"Delhi","Pune","Delhi",None]
})

# %%
df
# Out:
#     Name   Age   Salary   City
# 0   Amit  22.0  50000.0  Delhi
# 1   Riya  25.0  60000.0    NaN
# 2   John  30.0      NaN  Delhi
# 3   Sara   NaN  65000.0   Pune
# 4   Amit  20.0      NaN  Delhi
# 5  Sneha  31.0  63000.0    NaN

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#    Name   Age   Income   City
# 0  Amit  22.0  50000.0  Delhi

# %%
df_dropped = df.dropna()

# %%
df_dropped
# Out:
#    Name   Age   Salary   City
# 0  Amit  22.0  50000.0  Delhi

# %%
df_age_drop = df.dropna(subset=["Age","Salary"])
df_age_drop
# Out:
#     Name   Age   Salary   City
# 0   Amit  22.0  50000.0  Delhi
# 1   Riya  25.0  60000.0    NaN
# 5  Sneha  31.0  63000.0    NaN

# %%
df.rename(columns={"Salary":"Income"},inplace=True)

# %%
df
# Out:
#     Name   Age   Income   City
# 0   Amit    22  50000.0  Delhi
# 1   Riya    25  60000.0    NaN
# 2   John    30      NaN  Delhi
# 3   Sara  <NA>  65000.0   Pune
# 4   Amit    20      NaN  Delhi
# 5  Sneha    31  63000.0    NaN

# %%
df.dtypes
# Out:
# Name          str
# Age         Int64
# Income    float64
# City          str
# dtype: object

# %%
df['Age'] = df['Age'].astype('Int64')

# %%
df['City'].value_counts()
# Out:
# City
# Delhi    3
# Pune     1
# Name: count, dtype: int64

# %%
df['City'].unique()
# Out:
# <StringArray>
# ['Delhi', nan, 'Pune']
# Length: 3, dtype: str

# %%
df.sort_values("Age",ascending=False,inplace=True)

# %%
df.sort_index(inplace=True)

# %%
df
# Out:
#     Name   Age   Income   City
# 0   Amit    22  50000.0  Delhi
# 1   Riya    25  60000.0    NaN
# 2   John    30      NaN  Delhi
# 3   Sara  <NA>  65000.0   Pune
# 4   Amit    20      NaN  Delhi
# 5  Sneha    31  63000.0    NaN
