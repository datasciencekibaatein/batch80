# %%
import numpy as np

# %%
arr = np.array([1,2,3,4,5,5,6,6],dtype=np.float16)

# %%
arr.itemsize
# Out:
# 2

# %%
arr = np.array([2,3,5,6,6,7],dtype=np.float32)

# %%
arr.itemsize
# Out:
# 4

# %% [markdown]
# <h2>Indexing and Slicing</h2>

# %%
arr = np.array([23,
                67,
                89,
                45,
                56,
                78,
                34,
                89,
                20])

# %%
arr.ndim
# Out:
# 1

# %%
arr
# Out:
# array([23, 67, 89, 45, 56, 78, 34, 89, 20])

# %%
arr[2]
# Out:
# np.int64(89)

# %%
for i in arr:
    print(i)
# Out:
# 23
# 67
# 89
# 45

# %%
arr[2:7]
# Out:
# array([89, 45, 56, 78, 34])

# %% [markdown]
# 2D Matrix

# %%
matrix = np.array(
    [[2,4,3],
     [6,5,9],
     [0,4,8]]
)

# %%
matrix.ndim
# Out:
# 2

# %%
print(matrix)
# Out:
# [[2 4 3]
#  [6 5 9]
#  [0 4 8]]

# %%
matrix[2][1:3]
# Out:
# array([4, 8])

# %%
matrix = np.array(
    [[2,4,3],
     [6,5,9],
     [0,4,8]]
)

# %%
matrix[1:,0:2]
# Out:
# array([[6, 5],
#        [0, 4]])

# %% [markdown]
# <h2>Reshaping & Flattening Arrays</h2>

# %%
arr = np.arange(6)

# %%
arr
# Out:
# array([0, 1, 2, 3, 4, 5])

# %%
arr.reshape(1,6)
# Out:
# array([[0, 1, 2, 3, 4, 5]])

# %%
temp = matrix.flatten()

# %%
temp
# Out:
# array([2, 4, 3, 6, 5, 9, 0, 4, 8])

# %%
matrix.ravel()
# Out:
# array([2, 4, 3, 6, 5, 9, 0, 4, 8])

# %%
matrix
# Out:
# array([[2, 4, 3],
#        [6, 5, 9],
#        [0, 4, 8]])

# %% [markdown]
# <h2>Mathematical Operations</h2>

# %%
a = np.array([2,4,2])
b = np.array([5,8,3])

a_ = np.array([[3],
               [2],
               [1]])

# %% [markdown]
# <h3 style="color:green;">Vector Calculation</h3>

# %%
a+b
# Out:
# array([ 7, 12,  5])

# %%
a-b
# Out:
# array([-3, -4, -1])

# %%
a*b
# Out:
# array([10, 32,  6])

# %%
np.add(a,b)
# Out:
# array([ 7, 12,  5])

# %%
np.multiply(a,b)
# Out:
# array([10, 32,  6])

# %%
np.subtract(a,b)
# Out:
# array([-3, -4, -1])

# %%
np.divide(a,b)
# Out:
# array([0.4       , 0.5       , 0.66666667])

# %% [markdown]
# <h3 style="color:green;">Scaler Calculation</h3>

# %%
a * 3
# Out:
# array([ 6, 12,  6])

# %%
a - 5
# Out:
# array([-3, -1, -3])

# %%
a + 3
# Out:
# array([5, 7, 5])

# %% [markdown]
# <h3>Aggregation Functions</h3>

# %%
arr = np.array([34,23,67,45,56,29])

# %%
np.sum(arr)
# Out:
# np.int64(254)

# %%
np.mean(arr)
# Out:
# np.float64(42.333333333333336)

# %%
np.median(arr)
# Out:
# np.float64(39.5)

# %%
np.std(arr)
# Out:
# np.float64(15.402020069530563)

# %%
np.var(arr)
# Out:
# np.float64(237.22222222222226)

# %%
np.min(arr)
# Out:
# np.int64(23)

# %%
np.max(arr)
# Out:
# np.int64(67)

# %%
np.argmin(arr)
# Out:
# np.int64(1)

# %%
np.argmax(matrix)
# Out:
# np.int64(5)

# %%
matrix
# Out:
# array([[2, 4, 3],
#        [6, 5, 9],
#        [0, 4, 8]])

# %% [markdown]
# <h3>Boolean & Filtering</h3>

# %%
arr = np.array([34,23,67,45,56,29])

# %%
arr > 30
# Out:
# array([ True, False,  True,  True,  True, False])

# %%
arr[(arr > 30) & (arr < 60) & (arr != 45)]
# Out:
# array([34, 56])

# %%
(arr > 30) & (arr < 60) & (arr != 45)
# Out:
# array([ True, False, False, False,  True, False])
