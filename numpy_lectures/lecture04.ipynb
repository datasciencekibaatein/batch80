# %%
import numpy as np

# %% [markdown]
# Sorting (return the copy of sorted array)

# %%
arr = np.array([3,5,2,8,6,1])

sorted_arr = np.sort(arr)

# %%
sorted_arr
# Out:
# array([1, 2, 3, 5, 6, 8])

# %% [markdown]
# Returns the indices of sorted array

# %%
np.argsort(arr)
# Out:
# array([5, 2, 0, 1, 4, 3])

# %% [markdown]
# we can put if-else like condition for array

# %%
np.where(arr>5,"High","Low")
# Out:
# array(['Low', 'Low', 'Low', 'High', 'High', 'Low'], dtype='<U4')

# %%
np.where(arr>5)
# Out:
# (array([3, 4]),)

# %%
sorted_arr
# Out:
# array([1, 2, 3, 5, 6, 8])

# %% [markdown]
# Returns you the position of index , where you can insert elements

# %%
np.searchsorted(sorted_arr,4)
# Out:
# np.int64(3)

# %%
np.searchsorted(sorted_arr,[4,9])
# Out:
# array([3, 6])

# %%
arr1 = np.array([1,2,2,3,2,4,4,5,3])

# %% [markdown]
# Remove duplicacy from the array

# %%
np.unique(arr1)
# Out:
# array([1, 2, 3, 4, 5])

# %%
np.unique(arr1,return_counts=True)
# Out:
# (array([1, 2, 3, 4, 5]), array([1, 3, 2, 2, 1]))

# %% [markdown]
# Concatenate

# %%
a = np.array([[1,2]])
b = np.array([[3,4]])

# %%
np.concatenate((a,b),axis=0)
# Out:
# array([[1, 2],
#        [3, 4]])

# %% [markdown]
# vstack

# %%
np.vstack((a,b))
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
np.hstack((a,b))
# Out:
# array([[1, 2, 3, 4]])

# %%
arr
# Out:
# array([3, 5, 2, 8, 6, 1])

# %% [markdown]
# split()

# %%
np.split(arr,3)
# Out:
# [array([3, 5]), array([2, 8]), array([6, 1])]

# %% [markdown]
# copy()

# %%
a = np.array([1,2,3])

b = a.copy()

# %%
a[1] = 4

# %%
a
# Out:
# array([1, 4, 3])

# %%
b
# Out:
# array([1, 2, 3])

# %% [markdown]
# view()

# %%
a = np.array([3,4,2])

b = a.view()

b
# Out:
# array([3, 4, 2])

# %%
a[1] = 3

# %%
b
# Out:
# array([3, 3, 2])

# %%
type(arr)
# Out:
# numpy.ndarray

# %%
arr2 = np.asarray([3,4,3])
type(arr2)
# Out:
# numpy.ndarray

# %%
arr3 = np.array([1,3,2,4,np.nan,5,6,np.nan])

# %%
np.isnan(arr3).sum()
# Out:
# np.int64(2)

# %%
np.mean(arr3)
# Out:
# np.float64(nan)

# %%
np.median(arr3)
# Out:
# np.float64(nan)

# %%
np.nanmean(arr3)
# Out:
# np.float64(3.5)

# %%
np.nanmedian(arr3)
# Out:
# np.float64(3.5)

# %%
a = np.array([1,2,3])
b = np.array([4,5,6])

np.dot(a,b)
# Out:
# np.int64(32)

# %%
mat1 = np.array(
    [[1,2,3],
    [2,1,2],
    [2,2,1]])

mat2 = np.array([
[2,2,1],
[2,3,4],
[2,3,5]])


np.dot(mat1,mat2)
# Out:
# array([[12, 17, 24],
#        [10, 13, 16],
#        [10, 13, 15]])

# %%
mat1 @ mat2
# Out:
# array([[12, 17, 24],
#        [10, 13, 16],
#        [10, 13, 15]])

# %%
inv_mat1 = np.linalg.inv(mat1)

# %%
A = np.array([[1,2],
[3,4]])

# %%
A
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
inv_A = np.linalg.inv(A)

# %%
inv_A
# Out:
# array([[-2. ,  1. ],
#        [ 1.5, -0.5]])

# %%
A * inv_A
# Out:
# array([[-2. ,  2. ],
#        [ 4.5, -2. ]])
